# %%
from PIL import Image, ImageFilter, ImageEnhance, ImageDraw
img=Image.open("task#1.png")
size=img.size
print(size)
img2=img.resize((320,235), resample = 0 , box = None )
img2=img2.rotate(180, resample = 0 , expand = 0 , center = None , translate = None , fillcolor = None )
img.paste(img2,(397,360))
#img.show()
# Out:
# (1100, 698)

# %%
img3=img.resize((85,83), resample = 0 , box = None )
img.paste(img3,(512,394))
#img.show()

# %%
from PIL import ImageFilter, ImageEnhance
img=img.convert( mode = "L" , matrix = None , dither = None , palette = 0 , colors = 256 )
im = ImageEnhance.Contrast(img)
im.enhance(1.5)
# Out:
# <PIL.Image.Image image mode=L size=1100x698 at 0x19B2C513BE0>

# %%
img=img.resize((550,349), resample = 0 , box = None )
size = img.size 
format = img.format 
mode = img.mode 
arr=str(size)+" ; "+str(format)+" ; "+str(mode)
draw = ImageDraw.Draw(img)
draw.text((50, 50), arr1, fill=128, font=None, anchor=None, spacing=0, align="left", direction=None, features=None)
img.show()

# %%
img.save("task#2.png")
